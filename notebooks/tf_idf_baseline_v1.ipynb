# %%
# !git clone https://github.com/Nusultan11/imdb-sentiment.git
# %cd /content/imdb-sentiment
# Out:
# Cloning into 'imdb-sentiment'...
# remote: Enumerating objects: 207, done.
# remote: Counting objects: 100% (207/207), done.
# remote: Compressing objects: 100% (123/123), done.
# remote: Total 207 (delta 87), reused 178 (delta 59), pack-reused 0 (from 0)
# Receiving objects: 100% (207/207), 52.81 KiB | 3.77 MiB/s, done.
# Resolving deltas: 100% (87/87), done.
# /content/imdb-sentiment

# %%
# !pip install -q -e .
# Out:
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for imdb-sentiment (pyproject.toml) ... done

# %%
# !python -m imdb_sentiment.cli --config configs/baseline.yaml
# Out:
# README.md: 7.81kB [00:00, 20.7MB/s]
# ...
# plain_text/train-00000-of-00001.parquet: 100% 21.0M/21.0M [00:00<00:00, 25.4MB/s]
# plain_text/test-00000-of-00001.parquet: 100% 20.5M/20.5M [00:00<00:00, 49.9MB/s]
# plain_text/unsupervised-00000-of-00001.p(…): 100% 42.0M/42.0M [00:00<00:00, 68.7MB/s]
# Generating train split: 100% 25000/25000 [00:00<00:00, 109773.25 examples/s]
# Generating test split: 100% 25000/25000 [00:00<00:00, 157197.19 examples/s]
# Generating unsupervised split: 100% 50000/50000 [00:00<00:00, 136601.37 examples/s]
# Training finished.
# Accuracy: 0.8976
# Precision: 0.8994
# Recall: 0.8958
# F1: 0.8976
# Model saved to: artifacts/models/baseline.joblib
# Metrics saved to: artifacts/reports/metrics.json

# %%
# !ls -R artifacts
# Out:
# artifacts:
# models	reports
#
# artifacts/models:
# baseline.joblib
#
# artifacts/reports:
# metrics.json

# %%
import json
from pathlib import Path
import shutil
from google.colab import files

# %%
metrics_path = Path("artifacts/reports/metrics.json")
print(metrics_path.read_text(encoding="utf-8"))

metrics = json.loads(metrics_path.read_text(encoding="utf-8"))
metrics
# Out:
# {
#   "accuracy": 0.8976,
#   "precision": 0.8994391025641025,
#   "recall": 0.8958499600957701,
#   "f1": 0.897640943622551
# }
# {'accuracy': 0.8976,
#  'precision': 0.8994391025641025,
#  'recall': 0.8958499600957701,
#  'f1': 0.897640943622551}

# %%
model_path = Path("artifacts/models/baseline.joblib")
print("Model exists:", model_path.exists())
print("Model path:", model_path)
# Out:
# Model exists: True
# Model path: artifacts/models/baseline.joblib

# %%
archive_path = shutil.make_archive("imdb_artifacts", "zip", "artifacts")
print("Archive created:", archive_path)
files.download(archive_path)
# Out:
# Archive created: /content/imdb-sentiment/imdb_artifacts.zip
