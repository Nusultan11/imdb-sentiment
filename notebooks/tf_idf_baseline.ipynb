# %%
# !git clone https://github.com/Nusultan11/imdb-sentiment.git
# %cd imdb-sentiment
# Out:
# Cloning into 'imdb-sentiment'...
# remote: Enumerating objects: 152, done.
# remote: Counting objects: 100% (152/152), done.
# remote: Compressing objects: 100% (89/89), done.
# remote: Total 152 (delta 61), reused 134 (delta 43), pack-reused 0 (from 0)
# Receiving objects: 100% (152/152), 40.28 KiB | 5.03 MiB/s, done.
# Resolving deltas: 100% (61/61), done.
# /content/imdb-sentiment

# %%
# !git pull origin master
# !git log -1 --oneline
# Out:
# remote: Enumerating objects: 45, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 27 (delta 16), reused 27 (delta 16), pack-reused 0 (from 0)
# Unpacking objects: 100% (27/27), 4.90 KiB | 716.00 KiB/s, done.
# From https://github.com/Nusultan11/imdb-sentiment
#  * branch            master     -> FETCH_HEAD
#    745cd75..1f7c6d1  master     -> origin/master
# Updating 745cd75..1f7c6d1
# Fast-forward
#  AGENTS.md                                 | 313 +++++++++++++-----------------
#  README.md                                 |   7 +-
#  src/imdb_sentiment/cli.py                 |  47 ++---
#  src/imdb_sentiment/data/dataset.py        |  28 ++-
#  src/imdb_sentiment/features/preprocess.py |   2 +-
#  src/imdb_sentiment/inference/predict.py   |  12 +-
#  src/imdb_sentiment/pipelines/train.py     |  13 +-
#  src/imdb_sentiment/settings.py            |  39 ++--
#  tests/test_inference.py                   |  22 ---
# ...

# %%
# !pip install -q -e .[dev]
# Out:
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for imdb-sentiment (pyproject.toml) ... done

# %%
# !ls
# !ls configs
# !ls src/imdb_sentiment
# Out:
# AGENTS.md  configs  notebooks	    README.md  tests
# artifacts  data     pyproject.toml  src
# baseline.yaml
# cli.py	features   __init__.py	pipelines    settings.py
# data	inference  models	__pycache__

# %%
# !PYTHONPATH=src python -m imdb_sentiment.cli --config configs/baseline.yaml
# Out:
# Training finished.
# Accuracy: 0.8950
# Precision: 0.8922
# Recall: 0.8985
# F1: 0.8953
# Model saved to: artifacts/models/baseline.joblib
# Metrics saved to: artifacts/reports/metrics.json

# %%
# !ls artifacts/models
# !ls artifacts/reports
# !cat artifacts/reports/metrics.json
# Out:
# baseline.joblib
# metrics.json
# {
#   "accuracy": 0.89496,
#   "precision": 0.892198919605974,
#   "recall": 0.89848,
#   "f1": 0.8953284438775511
# }

# %%
import sys
sys.path.append("src")
from imdb_sentiment.inference.predict import load_model, predict_texts
from google.colab import files

# %%
model = load_model("artifacts/models/baseline.joblib")

texts = [
    "This movie was fantastic, I loved every minute of it.",
    "Terrible movie. Boring and badly acted."
]

preds = predict_texts(model, texts)
print(preds)
# Out:
# [1, 0]

# %%
# !zip -j imdb_artifacts.zip artifacts/models/baseline.joblib artifacts/reports/metrics.json
# Out:
#   adding: baseline.joblib (deflated 59%)
#   adding: metrics.json (deflated 21%)

# %%
files.download("imdb_artifacts.zip")
